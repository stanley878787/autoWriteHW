# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://yamol.tw/item-783395.htm")

# %%
ans = driver.find_element_by_class_name("col-sm-6.col-md-4.col-lg-4")

# %%
answer = ans.text.split("\n")[0].split("：")[1]

# %%
selects = driver.find_element_by_class_name("itemcontent")

# %%
if answer == "A":
    number = 5
    selects.text.split("#")[0].split("\n(")[1-number].split(")")[1]
elif answer == "B":
    number = 4
    selects.text.split("#")[0].split("\n(")[1-number].split(")")[1]
elif answer == "C":
    number = 3
    selects.text.split("#")[0].split("\n(")[1-number].split(")")[1]
elif answer == "D":
    number = 2
    selects.text.split("#")[0].split("\n(")[1-number].split(")")[1]
    
selects.text.split("#")[0].split("\n(")[1-number].split(")")[1]


# A=5
# B=4
# C=3
# D=2
# Out:
# '商業所有會計處理均應根據原始憑證，編製記帳憑證，再據以登入帳簿'

# %%
# bcs = driver.find_elements(By.XPATH, '/html/body/div/b/a')

# %%
# driver.find_element_by_class_name("col-sm-6.col-md-4.col-lg-4")

# %%
driver.get("http://onlinetest1-3.slhs.tp.edu.tw/test2/main/simulate_exec.asp?gexamid=t14900&pcount=80&pastid=all")

# %%
driver.find_elements_by_name("examinterface")[1].click()

# %%
driver.find_element_by_id("n1").click()

# %%
driver.find_element_by_partial_link_text('開始測驗').click()

# %%
driver.switch_to.frame("main")

# %%
questions = driver.find_elements(By.XPATH, '/html/body/center/form/div/table/tbody/tr')

# %%
for i in range(2, len(questions)):
    print(questions[i].text.split(' ')[3])
# Out:
# 帳冊的記載應符合
# 分析交易以作分錄時，首應注意
# 應過入應付帳款貸方$10,000，卻誤過入借方，對餘額式試算表之影響為何
# 設運送條件為目的地交貨，貨到收款，若由買方墊付運費，則買方支付此筆運費之分錄可為貸記現金，借記
# 下列何者可能具有混合性質的帳戶
# 某商店年初資產$60,000、負債$40,000，當年增資$5,000，收益$3,000。若期末資產$70,000、負債$45,000，則當年費損應為
# 利用不正當方法致使會計事項或財務報表發生不實之結果者，商業負責人、主辦及經辦會計人員或依法受託代他人處理會計事務之人員，最高可處【　　】以下有期徒刑
# 期末調整分錄要輸入會計總帳系統時，較適合採取下列哪一種方式處理
# 下列何項不是Internet所賦予的良性功能
# 結帳後費損帳戶
# 下列有關權責發生基礎的敘述，何者有誤
# 下列敘述何者正確
# 會計程序缺少調整工作，則無法
# 下列何項最可能不會影響權益
# 下列何者非類頁欄之功用
# 誤將資產作費損入帳，使當年帳面上之淨利數
# 採應計基礎下，應收帳款確定無法收回時應
# 調整前混合帳戶的情形有
# 下列會計程序何者可省略，惟仍不影響報表之正確
# 1月份發現上年底盤點存貨時，漏點$12,000，則在上年度，期初存貨、期末存貨、銷貨成本、淨利等各項餘額中，有幾項被高估
# 期末調整之目的在於
# 電腦化總帳系統中的檔案有
# 企業對企業間需要電子資料交換的功能是因為
# 採用權責基礎記帳，期末將當期應享有之收入由下列何者轉為收益
# 不動產、廠房及設備用直線法計算折舊，則每年終調整後之帳面金額
# 雙式簿記
# 依據商業會計法第四十條內容規定電子方式有關「內部控制、輸入資料之授權與簽章方式、會計資料之儲存、保管、更正及其他相關事項」之辦法，須由下列何機關定之
# 資產負債表與綜合損益表之連鎖關係在於
# 存貨若係透過銷貨成本帳戶來調整，則調整後試算表上之存貨金額係屬
# 期末應收帳款借餘$200,000，調整前備抵損失－應收帳款借餘$4,000，按應收帳款餘額計提3%之備抵損失，則調整後備抵損失－應收帳款餘額為
# 我國商業會計法規定會計帳簿分為
# 系統設計時，有關會計總帳作業之財務報表，下列敘述何者有誤
# 賒銷商品$5,000，誤記為賒購商品，將使餘額式試算表之借貸方餘額
# 下列何者不是數據機(Modem)的功能
# 若有一付款條件為2/10，n/30，EOM；表示折扣期間與授信期限均自【　　】在30天內一定要還款，若在10天內還款，給予貨款總額2%的折扣
# 為便於查閱，在試算表中多加一類頁欄，其內容為
# 下列何者得不在日記簿作分錄
# 已知進貨退出及折讓$7,360，進貨費用$3,840，銷貨成本$67,040，進貨$104,000，期末存貨$61,520，則期初存貨為
# 電腦系統產生之權益變動表屬於那一類報表
# 存貨若係透過銷貨成本帳戶來調整，則調整前試算表上之存貨金額係屬
# 下列何者非為會計之功能
# 下列敘述何者錯誤
# 結算工作底稿中，調整前試算表欄之預收租金$9,800，其調整分錄欄借方列示預收租金$5,300，在資產負債欄之預收租金為
# 欣妮公司101年10月1日購入機器一台$800,000，殘值$50,000，採直線法計提折舊，103年初帳面金額為$753,125，則下列敘述何者為正確
# 日記簿是每一企業的
# 企業若發生一筆交易，一方面使其資產增加，則另一方面可能使其
# 下列哪一帳戶在編製結帳分錄結清其餘額時，需要貸記本期損益帳戶
# 分類帳的主要功用為
# 當已驗收完畢的商品，日後發現有瑕疵而要退給供應商時，依據加值型及非加值型營業稅法規定，公司應使用下列哪一張單據處理
# 若銷貨毛利率（銷貨毛利÷銷貨淨額）為25%，則銷貨成本毛利率(銷貨毛利÷銷貨成本)為
# 台中公司之流動資產$64,350，流動負債$49,500，今有一張應付票據$36,000到期兌付，則其流動比率為
# 在Windows作業系統中，下列哪些項目不可拖曳至資源回收筒而將其刪除
# 台中商店於03年9月15日預收佣金$60,000，當時以佣金收入帳戶入帳，年終估計已提供勞務程度有80％，則期末調整應
# 採加值型營業稅時，若銷項稅額大於進項稅額，即產生
# 仁愛商店在創業期間支付律師酬勞金$11,000，則應借記
# 以下何者不屬於通訊網路的組成元件
# 會計資訊認定及報導的門檻，乃指
# 應收帳款統制帳戶有借餘$100,000，明細內容有三帳戶，已知李君借餘$35,000，王君借餘$50,000，則林君餘額為何
# 銷貨運費在綜合損益表中應列於
# 費用業已發生，但尚未入帳，期末調整應
# 電腦化總帳系統中的檔案有
# 下列敘述何者正確
# 銷貨淨額$100,000，銷貨毛利$20,000，則成本率為
# 交易事項對財務報表之精確性無重大影響者
# 安全門或緊急出口平時應維持何狀態？
# 腕道症候群常發生於下列何作業？
# 「勞工腦心血管疾病發病的風險與年齡、抽菸、總膽固醇數值、家族病史、生活型態、心臟方面疾病」之相關性為何？
# 有關高風險或高負荷、夜間工作之安排或防護措施，下列何者不恰當？
# 有關專利權的敘述，何者正確？
# 根據性別工作平等法，有關雇主防治性騷擾之責任與罰則，下列何者錯誤?
# 有關菸害防制法規範，「不可販賣菸品」給幾歲以下的人？
# 對於依照個人資料保護法應告知之事項，下列何者不在法定應告知的事項內？
# 森林面積的減少甚至消失可能導致哪些影響：A.水資源減少
# 下列何種行為無法減少「溫室氣體」排放？
# 某工廠產生之廢棄物欲再利用，應依何種方式辦理？
# 哪一種氣體造成臭氧層被嚴重的破壞？
# 透過淋浴習慣的改變就可以節約用水，以下的何種方式正確？
# 關於綠色採購的敘述，下列何者錯誤？
# 蓮篷頭出水量過大時，下列何者無法達到省水？
# 為了取得良好的水資源，通常在河川的哪一段興建水庫？

# %%
questions[2].text.split(' ')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-15-d3d6e9eb6e50> in <module>
# ----> 1 questions[2].text.split(' ')
#
# c:\users\a0968\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# c:\users\a0968\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# c:\users\a0968\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\users\a0968\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=92.0.4515.131)

# %%
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-14-a86089ef405e> in <module>
# ----> 1 questions[2].text.split(' ')[3]
#
# c:\users\a0968\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# c:\users\a0968\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# c:\users\a0968\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\users\a0968\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=92.0.4515.131)

# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get("https://yamol.tw/item-783394.htm")

# %%
soup     = BeautifulSoup(response.text, 'html.parser')

# %%
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang=""> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>4.商業支出超過下列何種金額以上者，應使用匯票、本票、支票、劃撥或其他經主管機關..-阿摩線上測驗</title>
# <meta content="" property="fb:admins">
# <meta content="213343434487" property="fb:app_id">
# <meta content="4.商業支出超過下列何種金額以上者，應使用匯票、本票、支票、劃撥或其他經主管機關..-阿摩線上測驗" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="" property="og:description"/>
# <meta content="app-id=1420850845" name="apple-itunes-app"/>
# <meta content="app-id=com.yamol.exam" name="google-play-app"/>
# <meta content="17251231005746477" property="qc:admins">
# <meta content="783394" name="dable:item_id"> <meta content="https://yamol.tw/item-4.%E5%95%86%E6%A5%AD%E6%94%AF%E5%87%BA%E8%B6%85%E9%81%8E%E4%B8%8B%E5%88%97%E4%BD%95%E7%A8%AE%E9%87%91%E9%A1%8D%E4%BB%A5%E4%B8%8A%E8%80%85%EF%BC%8C%E6%87%89%E4%BD%BF%E7%94%A8%E5%8C%AF%E7%A5%A8%E3%80%81%E6%9C%AC%E7%A5%A8%E3%80%81%E6%94%AF%E7%A5%A8%E3%80%81%E5%8A%83%E6%92%A5%E6%88%96%E5%85%B6%E4%BB%96%E7%B6%93%E4%B8%BB%E7%AE%A1%E6%A9%9F%E9%97%9C..-783394.htm" name="og:url"/> <meta content="站僕" name="dable:author"/> <meta content="技檢◆會計事務-丙級" name="article:section"/> <meta content="2015/04/14 14:07:30" name="article:published_time"/>
# <meta content="技檢◆會計事務-丙級,試題" name="keywords"/> <meta content="_9CLoaf0HHlwRJl4biVwTUQekfs" name="alexaVerifyID"/>
# <link href="https://cdn.yamol.net/images/logo_new.jpg?2021070801" rel="image_src" type="image/jpeg"/>
# <meta content="https://cdn.yamol.net/images/logo_new.jpg?2021070801" property="og:image"/>
# <link href="https://cdn.yamol.net/images/favicon.ico?2021070801" rel="shortcut icon"/>
# <link href="https://yamol.tw/item-4.%E5%95%86%E6%A5%AD%E6%94%AF%E5%87%BA%E8%B6%85%E9%81%8E%E4%B8%8B%E5%88%97%E4%BD%95%E7%A8%AE%E9%87%91%E9%A1%8D%E4%BB%A5%E4%B8%8A%E8%80%85%EF%BC%8C%E6%87%89%E4%BD%BF%E7%94%A8%E5%8C%AF%E7%A5%A8%E3%80%81%E6%9C%AC%E7%A5%A8%E3%80%81%E6%94%AF%E7%A5%A8%E3%80%81%E5%8A%83%E6%92%A5%E6%88%96%E5%85%B6%E4%BB%96%E7%B6%93%E4%B8%BB%E7%AE%A1%E6%A9%9F%E9%97%9C..-783394.htm" rel="canonical"/>
# <link href="https://cdn.yamol.net/style/glyphicons_pro/css/glyphicons.css?2021070801" rel="stylesheet"/>
# <link href="https://cdn.yamol.net/style/glyphicons_halflings/css/halflings.css?2021070801" rel="stylesheet"/>
# <link href="https://cdn.yamol.net/style/glyphicons/css/social.css?2021070801" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:400italic,600italic,700italic,400,600,700" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Oswald:400,300,700" rel="stylesheet"/>
# <link href="https://cdn.yamol.net/style/theme_2015/css/font-awesome.min.css?2021070801" rel="stylesheet"/>
# <link href="https://cdn.yamol.net/style/theme_2015/css/bootstrap.min.css?2021070801" rel="stylesheet"/>
# <link href="https://cdn.yamol.net/style/theme_2015/js/plugins/morris/morris.css?2021070801" rel="stylesheet"/>
# <link href="https://cdn.yamol.net/style/theme_2015/js/plugins/icheck/skins/minimal/blue.css?2021070801" rel="stylesheet"/>
# <link href="https://cdn.yamol.net/style/theme_2015/js/plugins/select2/select2.css?2021070801" rel="stylesheet"/>
# <link href="https://cdn.yamol.net/style/theme_2015/js/plugins/fullcalendar/fullcalendar.css?2021070801" rel="stylesheet"/>
# <link href="https://cdn.yamol.net/composer/vendor/twbs/bootstrap/dist/css/bootstrap.min.css?2021070801" rel="stylesheet"/>
# <link href="https://cdn.yamol.net/plugin/jquery-ui-1.12.1.custom/jquery-ui.css?2021070801" rel="stylesheet"/>
# <link href="https://cdn.yamol.net/style/theme_2015/css/target-admin_2015.css?2021070801" rel="stylesheet"/>
# <link href="https://cdn.yamol.net/style/theme_2015/css/custom.css?2021070801" rel="stylesheet"/>
# <!--[if lt IE 9]>
#   <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
#   <script src="https://oss.maxcdn.com/libs/respond.js/1.3.0/respond.min.js"></script>
#   <![endif]-->
# <script src="https://cdn.yamol.net/newlib/js/jquery-1.10.2.js?&amp;2021070801"></script>
# <script src="https://cdn.yamol.net/newlib/js/jquery-ui.1.11.4.js?&amp;2021070801"></script>
# <script src="https://cdn.yamol.net/newlib/js/stupidtable.min.js?2021070801"></script>
# <link href="https://cdn.yamol.net/composer/node_modules/chosen-js/chosen.css?2021070801" rel="stylesheet">
# <link href="https://cdn.yamol.net/newlib/js/chosenImage/chosenImage.css?&amp;2021070801" rel="stylesheet">
# <script src="https://cdn.yamol.net/composer/node_modules/chosen-js/chosen.jquery.min.js?2021070801" type="text/javascript"></script>
# <script src="https://cdn.yamol.net/newlib/js/chosenImage/chosenImage.jquery.js?2021070801" type="text/javascript"></script>
# <script src="https://cdn.yamol.net/style/theme_2015/js/libs/bootstrap.min.js?2021070801"></script>
# <script src="https://cdn.yamol.net/composer/node_modules/slidereveal/dist/jquery.slidereveal.min.js?2021070801" type="text/javascript"></script>
# <link href="https://cdn.yamol.net/composer/node_modules/lightgallery/dist/css/lightgallery.min.css?2021070801" rel="stylesheet"/>
# <script src="https://cdn.yamol.net/composer/node_modules/lightgallery/dist/js/lightgallery.min.js?2021070801"></script>
# <script src="https://cdn.yamol.net/composer/node_modules/lg-zoom/dist/lg-zoom.js?2021070801"></script>
# <script src="https://cdn.yamol.net/plugin/jquery.mousewheel.min.js?2021070801"></script>
# <script src="https://cdn.yamol.net/composer/node_modules/bootpag/lib/jquery.bootpag.min.js?2021070801"></script>
# <link href="https://cdn.yamol.net/style/bootstrap_custom_2015.css?2021070801" rel="stylesheet">
# <!--[if lt IE 9]>
# 	  <script src="./js/libs/excanvas.compiled.js"></script>
# 	  <![endif]-->
# <script src="https://cdn.polyfill.io/v2/polyfill.min.js"></script>
# <script src="https://cdn.yamol.net/js/vue.js?&amp;2021070801"></script>
# <script src="https://cdn.jsdelivr.net/npm/axios/dist/axios.min.js"></script>
# <script src="https://cdn.yamol.net/style/theme_2015/js/target-admin.js?&amp;2021070801"></script>
# <script src="https://www.gstatic.com/firebasejs/7.10.0/firebase-app.js"></script>
# <script src="https://www.gstatic.com/firebasejs/7.10.0/firebase-auth.js"></script>
# <script src="https://www.gstatic.com/firebasejs/7.10.0/firebase-firestore.js"></script>
# <script src="https://www.gstatic.com/firebasejs/7.10.0/firebase-database.js"></script>
# <link href="https://cdn.yamol.net/widget/index.css?&amp;2021070801" rel="stylesheet">
# <script type="text/javascript">
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
# <script type="text/javascript">
# googletag.cmd.push(function() {
# googletag.defineSlot('/421373928/全站300x600', [[120, 600], [160, 600], [300, 600]], 'div-gpt-ad-1403163175253-0').addService(googletag.pubads());
# googletag.defineSlot('/421373928/全站上方97090', [[728, 90], [970, 90]], 'div-gpt-ad-1403163175253-1').addService(googletag.pubads());
# googletag.defineSlot('/421373928/全站左300x250', [[250, 250], [300, 250]], 'div-gpt-ad-1403163175253-2').addService(googletag.pubads());
# googletag.defineSlot('/421373928/全站左160x600', [160, 600], 'div-gpt-ad-1411380385945-0').addService(googletag.pubads());
# googletag.defineSlot('/421373928/全站左160x600', [160, 600], 'div-gpt-ad-1411380385945-1').addService(googletag.pubads());
# googletag.defineSlot('/421373928/全站左160x600', [160, 600], 'div-gpt-ad-1411380385945-2').addService(googletag.pubads());
# googletag.defineSlot('/421373928/全站左160x600', [160, 600], 'div-gpt-ad-1411380385945-3').addService(googletag.pubads());
# googletag.defineSlot('/421373928/全站左160x600', [160, 600], 'div-gpt-ad-1411380385945-4').addService(googletag.pubads());
# googletag.defineSlot('/421373928/全站左160x600', [160, 600], 'div-gpt-ad-1411380385945-5').addService(googletag.pubads());
# googletag.defineSlot('/421373928/全站左160x600', [160, 600], 'div-gpt-ad-1411380385945-6').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script>
# </link></link></link></link></meta></meta></meta></meta></head>
# <body>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NGJZ5QH" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div id="body_pre"></div>
# <div id="body">
# <div aria-hidden="true" aria-labelledby="myModalLabel" class="modal fade" id="myModal" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content2">
# <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# <h4 class="modal-title" id="modal-title"></h4>
# </div>
# <div class="modal-content" id="modal-body" style="padding:10px">
# <div>載入中..請稍候..</div>
# </div>
# <div class="modal-extra" id="modal-extra" style="padding:10px"></div>
# <div class="modal-footer" id="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button">關閉</button>
# </div>
# </div>
# </div>
# </div>
# <script>
# 	var host="https://yamol.tw/";
# 	var imgserver="https://yamol.tw/";
# 	var version="080732";
# 	var currenttime="1628326732";
# 	</script>
# <script src="https://cdn.yamol.net/newlib/js/basicFunctions_header.js?2021070801"></script>
# <script src="https://cdn.yamol.net/newlib/js/jquery.plugs.min.js?2021070801" type="text/javascript"></script>
# <script>
#
# $(function() {
# 	$( document ).ajaxComplete(function() {
# 	  $('[data-load-remote]').unbind('click');
# 	  $('[data-load-remote]').on('click',function(e) {
# 		e.preventDefault();
#
# 		var $this = $(this);
# 		var remote = $this.data('load-remote');
#
# 			if(remote) {
# 				$("#modal-body").load(remote+"&dialog=1");
# 			}
# 		});
# 	});
#  });
#
#
# </script>
# <script>
#   window.fbAsyncInit = function() {
#     FB.init({
#       appId      : '213343434487',
#       xfbml      : true,
#       version    : 'v2.9'
#     });
#     FB.AppEvents.logPageView();
#   };
#
#   (function(d, s, id){
#      var js, fjs = d.getElementsByTagName(s)[0];
#      if (d.getElementById(id)) {return;}
#      js = d.createElement(s); js.id = id;
#      js.src = "//connect.facebook.net/zh_TW/sdk.js?1323";
#      fjs.parentNode.insertBefore(js, fjs);
#    }(document, 'script', 'facebook-jssdk'));
# </script>
# <link href="https://cdn.yamol.net/plugin/animate.css?2021070801" rel="stylesheet" type="text/css"/>
# <script src="//cdnjs.cloudflare.com/ajax/libs/jquery-easing/1.3/jquery.easing.min.js"></script>
# <script charset="utf-8" src="https://cdn.yamol.net/plugin/aehlke-tag-it/js/tag-it.js?2021070801" type="text/javascript"></script>
# <script src="https://cdn.yamol.net/plugin/jQuery-Bootstrap-Based-Toast-Notification-Plugin-toaster/jquery.toaster.js?2021070801"></script>
# <link href="https://cdn.yamol.net/plugin/aehlke-tag-it/css/jquery.tagit.css?2021070801" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.yamol.net/plugin/aehlke-tag-it/css/tagit.ui-zendesk.css?2021070801" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.yamol.net/composer/node_modules/summernote/dist/summernote.css?2021070801" rel="stylesheet"/>
# <script src="https://cdn.yamol.net/composer/node_modules/summernote/dist/summernote.min.js?2021070801"></script>
# <script src="https://cdn.yamol.net/newlib/lang/summernote-zh-TW.js?2021070801"></script>
# <script src="https://cdn.yamol.net/plugin/jq_scroll.js?2021070801"></script>
# <link href="https://cdn.yamol.net/composer/node_modules/intro.js/introjs.css?2021070801" rel="stylesheet"/>
# <script src="https://cdn.yamol.net/composer/node_modules/intro.js/intro.js?2021070801"></script>
# <link href="https://rawgit.com/tylerecouture/summernote-list-styles/master/summernote-list-styles.css" rel="stylesheet"/>
# <script src="https://rawgit.com/tylerecouture/summernote-list-styles/master/summernote-list-styles.js"></script>
# <script src="https://cdn.yamol.net/composer/node_modules/jquery-bar-rating/dist/jquery.barrating.min.js?2021070801"></script>
# <link href="https://cdn.yamol.net/composer/node_modules/jquery-bar-rating/dist/themes/bootstrap-stars.css?2021070801" rel="stylesheet"/>
# <style>
# pre{width:100%;}
# .ui-autocomplete{z-index:999999}
# .note-editor{padding:0px}
# .selfmemo{
# 	-webkit-border-top-right-radius: 20px;
# 	-webkit-border-bottom-left-radius: 20px;
# 	-moz-border-radius-topright: 20px;
# 	-moz-border-radius-bottomleft: 20px;
# 	border-top-right-radius: 20px;
# 	border-bottom-left-radius: 20px;
# 	text-align:left;
# 	border:3px solid #DAA520;
# 	padding:10px;
# 	word-wrap:break-word;
# }
#
# .drop-shadow {
#     -webkit-filter: drop-shadow(12px 12px 7px rgba(0, 0, 0, 0.7));
#     filter: drop-shadow(12px 12px 7px rgba(0, 0, 0, 0.7))
# }
#
# .div_shadow
# {
# box-shadow: 4px 5px 21px #333333;
# -webkit-box-shadow: 4px 5px 21px #333333;
# -moz-box-shadow: 4px 5px 21px #333333;
# }
# .div-radius
# {
# border-radius: 10px;
# -webkit-border-radius: 10px;
# -moz-border-radius: 10px;
# }
# .wantedbg{position: relative;width:440px;top:100px;left:80px}
# .wantedbtn{background-color:#563A36;border:1px solid #563A36;color:white}
# .headerchannel{list-style-type: none; padding: 0px;}
# .fixed {
# 	position: fixed;
# 	top: 0;
# }
# .reponse-card{text-valign:top; background-color: #fff; padding: 20px; margin-bottom: 20px; border-radius: 3px; border: 1px solid;
# 			border-color: #e5e6e9 #dfe0e4 #d0d1d5; padding: 40px;}
# .reponse-card .itemcontent{font-size:20px;line-height:140%}
# .reponse-card .itemcontent_dict{font-size:20px;line-height:140%}
# .sogreen{cursor:pointer;}
# .tran{background:yellow}
# .dictionary_off{color:gray}
# .navbar-nav{margin:0px;}
#  ul.sitemenu_sub>li{font-size:20px;line-height:170%}
# .want_item_body_bg{
# 	/* Permalink - use to edit and share this gradient: http://colorzilla.com/gradient-editor/#ffdb94+0,ffdb94+68,ffbf2c+90,ffcb54+100 */
# 	background: #ffdb94; /* Old browsers */
# 	background: -moz-linear-gradient(left, #ffdb94 0%, #ffdb94 68%, #ffbf2c 90%, #ffcb54 100%); /* FF3.6-15 */
# 	background: -webkit-linear-gradient(left, #ffdb94 0%,#ffdb94 68%,#ffbf2c 90%,#ffcb54 100%); /* Chrome10-25,Safari5.1-6 */
# 	background: linear-gradient(to right, #ffdb94 0%,#ffdb94 68%,#ffbf2c 90%,#ffcb54 100%); /* W3C, IE10+, FF16+, Chrome26+, Opera12+, Safari7+ */
# 	filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#ffdb94', endColorstr='#ffcb54',GradientType=1 ); /* IE6-9 */
# }
# .want_item_body_line{
# 	border:1px solid #FDEDC7;
# 	border-top:0px;
# 	border-bottom:0px;
# 	padding:10px;
# 	padding-top:30px;
#
# 	margin:0px 10px 10px 10px;
#
# }
# .want_item_footer{
# 	background-image:url(images/want/footer_flow.png);
# 	height:16px;
# 	margin:0 10px;
# 	position:relative;
# }
# .footerline{
# 	color:#FDEDC7;
# }
# .want_diamon_bg{
#
# 	position:absolute;left:-50px;top:-15px;
# 	padding-top:30px;
# 	height:173px;
# 	width:154px;
# 	background-image:url(images/want/want_diamond.png);
#
# }
# .want_bg_right{
# 	position:absolute;right:-2px;
# 	height:140px;
# 	width:171px;
# 	background-image:url(images/want/want_bg_right.png?2);
#
# }
# .want_bg_repeat{
# 	position:relative;
# 	background-image:url("images/want/want_bg_repeat.png?1");
# 	height:140px;
# 	right:-20px
# }
# .want_ansbtn{
# 	position:absolute;right:14px;top:85px;
# 	width:132px;height:47px;
# 	background-image:url("images/want/ansbtn.png?2");
# 	cursor:pointer;
# }
# .want_ansbtn:hover{
# 	background-image:url("images/want/ansbtn_on.png?2");
#
# }
# .want_diamond{
# 	display:block;
# 	background-image:url("images/usertasks/diamond.png?1");
# 	background-size: 50px 50px;
# 	width:50px;
# 	height:50px;
# }
# .diamond_nums{
# 	line-height:60px;
# 	display:block;
# 	font-size:60px;
# 	background-color: #816918;
#     -webkit-background-clip: text;
#     -moz-background-clip: text;
#     background-clip: text;
#     color: transparent;
#     text-shadow: rgba(255,255,255,0.5) 0px 3px 3px;
# 	font-weight:900;
# }
# .want_userwant{color:white;height:60px;position:relative;margin-left:110px;margin-right:15px;top:20px;font-size:18px;line-height:120%;overflow:auto}
#
# .want_itemnums{text-align:center;color:white;height:30px;position:relative;margin-left:110px;margin-right:160px;top:36px;font-size:18px;line-height:120%}
# .item_want_good_disable{width:68px;height:72px;background-image:url("images/want/item_want_good_disable.png?4");margin-right:10px;
# 	}
# .item_want_good{width:68px;height:72px;background-image:url("images/want/item_want_good.png?3");margin-right:10px;cursor:pointer;
# 	}
# .item_want_good:hover{width:68px;height:72px;background-image:url("images/want/item_want_good_on.png?3");margin-right:10px;cursor:pointer;
# 	}
# .want_item_rating_nums{margin-top:-10px;text-align:center;padding-top:5px;width:87px;height:30px;background-image:url("images/want/rating_bg.png?2");font-weight:600;color:white}
# .channel{height:28px;overflow: hidden;border-radius:5px;background-color:white;padding:5px}
# .mythumbs_up{cursor:pointer;padding-left:44px;background:url(images/thumbs_up.png?2);height:42px;width:44px}
# .mythumbs_up:hover{cursor:pointer;padding-left:44px;background:url(images/thumbs_up_on.png?2);height:42px;width:44px}
# .mythumbs_up_on{cursor:pointer;background-image:url("images/thumbs_up_on.png?2");height:42px;width:44px}
# .tab_highline{margin-top:9px;font-size:14px;height:26px}
# .tab_highline:hover{}
#
#
# .tab_highline > a{background-color:blue !important;;color:white !important;padding:3px !important}
# .tab_highline > a:hover,.tab_highline > a:focus{background-color:#e4e4e4 !important;color:black !important;}
# .symbol {
#   display: inline-block;
#   border-radius: 50%;
#   border: 5px double white;
#   width: 30px;
#   height: 30px;
# }
#
# .symbol-empty {
#   background-color: #ccc;
# }
#
# .symbol-filled {
#   background-color: black;
# }
# .starrating{
# font-size:30px;
# }
# .wanttitle{background-color:black;color:white}
# .wantclose{}
# .comment > table{border-collapse: collapse}
# .comment > table>tbody>tr>td{border:1px solid black}
# .comment > table>tr>td{border:1px solid black}
# .buymonth-button:hover {
# 	color: #dc0303;
# }
# .comment{
# 	line-height:170%;
# }
#
# .thumbs_color:before {
#     color: #0095e2
# }
# </style>
# <script>
# $(function () {
#   $('.mytooltip').tooltip();
# 	if($.isFunction($('.lightGallery').lightGallery)){
# 			  $(".myimg").each(function(){
# 				var src=$(this).attr('src');
# 				$(this).after("<span class='lightGallery'><A href='"+src+"'><img style='max-width:300px' src='"+src+"'></a></span>");
# 				$(this).remove();
# 			});
# 			$('.lightGallery').lightGallery({
# 				thumbnail:true,
# 				download:false
# 			});
# 	  }
#
#
# })
#
# function mytoast(message,title,priority){
# 	$.toaster({ priority : priority, title : title, message : message });
#
# }
# function showitemmemo2(type,itemid){
# 	$('#modal-body').load("ajax/itemmemoform.php?type="+type+"&itemid="+itemid+"&"+Math.random());
# 	$('#myModal').modal('show');
# }
# function delete_itemmemo(type,itemid){
# 	var memoid='memo'+type+itemid;
# 	//alert("刪除私人筆記 "+type+"=>"+itemid);
#
# 	// $.post( "ajax/itemmemo_del.php", { type:type,itemid: itemid } ).done(function(){
# 	// 	mytoast("成功","刪除成功");
# 	// });
# 	newApi.post('/v2/me/memos/destroy', {
# 		type,itemid
# 	}).then(response => {
# 		mytoast("成功","刪除成功");
# 	}).catch(error => {
#
# 	});
#
# 	$("#memo"+type+itemid).html("編輯私有筆記及自訂標籤").show();
# 	$('#pen'+memoid).show();
# 	$('#ajax_'+memoid).remove();
# 	$("#itemtags"+type+itemid).hide();
# 	var p=$("#memo"+type+itemid).offset();
#
# 	$("html, body").animate({ scrollTop: p.top-30 }, 600);
# }
#
# function sellmemo(type,obj){
# 	if(type=='open'){
# 		mytoast("您的全部私有筆記已經開啟販賣，每篇筆記將可以販賣10枚鑽石。");
# 		$.get("/ajax/itemmemo_open.php?op=open");
#
# 		$(obj).parent().html("目前販賣設定是開啟!<br><a onclick='sellmemo(\"close\",this)' class='btn btn-danger'>販賣中</a>");
#
#
# 	}else if(type=='close'){
# 		mytoast("您的全部私有筆記全部關閉販賣。");
# 		$.get("/ajax/itemmemo_open.php?op=close");
# 		$(obj).parent().html("你也可以將你的私有筆記拿來販賣，將可以賺取鑽石，每篇筆記將可以販賣10顆鑽石。<br><a onclick='sellmemo(\"open\",this)' class='btn btn-default'>開啟販賣</a>");
#
# 	}
#
# }
# function showitemmemo(type,itemid){
# 	var memoid='memo'+type+itemid;
#
# 	var p=$("#memo"+type+itemid).offset();
# 	$("html, body").animate({ scrollTop: p.top-30 }, 600);
# 	$('#pen'+memoid).hide();
# 	$('#'+memoid).after('<span id="ajax_'+memoid+'"></span>');
# 	$('#'+memoid).hide();
# 	$("#itemtags"+type+itemid).hide();
# 	$('#ajax_'+memoid).load("ajax/itemmemoform.php?type="+type+"&itemid="+itemid+"&"+Math.random());
# }
# function summernote(id,height,toolbar){
#
# 	const  queryString = window.location.search;
#
#
# 	var tmpheight=height?height:300;
#
# 	if(toolbar){
#
# 	}else{
# 		toolbar=[
# 		  ['style', ['style']],
# 		  ['styles', ['color','bold', 'italic', 'underline', 'strikethrough','superscript','subscript','clear']],
# 		  ['para', ['ol','listStyles', 'paragraph']],
#           ['Insert',['picture','link','table']],
# 		  ['misc',['fullscreen']],
# 		  ['mybutton', ['videoUpload']]
#         ] ;
# 	}
#
#
# 	var vimeoVideoUploadButton = function (context) {
#     	var ui = $.summernote.ui;
#
# 		// create button
# 		var button = ui.button({
# 			container: false,
# 			contents: '<i class="fa fa-video-camera" aria-hidden="true"></i>',
# 			tooltip: '上傳影片',
# 			click: function (e) {
# 				if ($('#myModal').hasClass('in')) {
# 					$('#myModal').find('#modal-extra').html("載入中").load("/ajax/upload_video.php?id="+id);
# 				} else {
# 					$('#myModal').modal('show');
# 					$('#myModal').find('#modal-body').html("載入中").load("/ajax/upload_video.php?id="+id);
# 				}
# 			}
# 		});
#
#       return button.render();   // return button as jquery object
#     }
#
#
# 	const isVideoUploadVisible =  id.includes('comment') ? true : false;
# 	const showVideoUpload = isVideoUploadVisible ? { videoUpload:vimeoVideoUploadButton } : {};
#
# 	$('#'+id).summernote(
# 	 {
# 	 	 dialogsInBody: true,
# 		 height: tmpheight,
# 		 focus: true,
# 		 lang: 'zh-TW',
# 		 toolbar: toolbar, callbacks: {
# 			onImageUpload: function(files, editor, welEditable)  {
# 				sendFile(files[0],editor,welEditable,id);
# 			}
# 		},
# 		buttons: showVideoUpload
# 	});
#
# }
#
# function Loading() {
#     var id = '_ModalLoading';
#     var selector = '#' + id;
#
#     return {
#         Show: function(msg) {
# 				var defaultmsg=msg?msg:"準備中，請稍候...";
# 			  var html = [
#         '<div class="modal fade" id="' + id + '">',
#             '<div class="modal-dialog" style="color: #fff; padding-top: 160px; text-align: center">',
#                 '<i class="fa fa-spinner fa-pulse fa-3x fa-fw margin-bottom" style="font-size:20px"></i>'+defaultmsg,
#             '</div>',
#         '</div>',
#     ].join('');
#             if($(selector).length < 1) {
#                 $('body').append(html);
#             }
#             $(selector).modal({ backdrop: 'static' });
#         },
#         Hide: function() {
#             $(selector).modal('hide');
#         },
#     };
# }
# var myloading=Loading();
# function sendFile(file, editor, welEditb,id) {
# 		myloading.Show();
#         var data = new FormData();
#         //data.append("image", image);
#         data.append("file", file);
#         $.ajax({
#             url: '/picasaupload.php',
#             cache: false,
#             contentType: false,
#             processData: false,
#             data: data,
#             type: "post",
# 			dataType:"json",
#             success: function (data) {
#                 //alert('display base64 data: ' + data.path);
#                 $('#'+id).summernote('insertImage', data.path,"");
# 				myloading.Hide();
#
#             },
#             error: function (data) {
#                 console.log(data);
# 				myloading.Hide();
#             }
#         });
#     }
#
#
# function additemcomment(obj,type,itemid){
# 	var comment = $('#comment_form'+type+itemid).summernote('code');
# 	var isEmpty = $('#comment_form'+type+itemid).summernote('isEmpty');
#     if (isEmpty) {
# 		alert("請先填發問的內容");
# 		return "";
# 	} else {
# 		var wrong=$('input[name=w'+type+itemid+']:checked').val();
# 		var sgid=$('#sgid_'+type+itemid).val();
# 		var want=$('#want_'+type+itemid).val();
#
# 		var isAutosell = $('#autosell-group-' + type+itemid).is(":checked");
#
# 		$.post("ajax.php", { "op": "comment_add","type":type,"want":want, "autosell": isAutosell, "sgid":sgid,"itemid": itemid,"comment":comment ,"wrong":wrong,'rand':Math.random()},function(data){
# 			$("#comment"+type+itemid).append(data);
# 		});
# 		$('#comment_form'+type+itemid).summernote('reset');
# 		$('#comment_form'+type+itemid).summernote('destroy');
# 		$('#comment_form'+type+itemid).val("");
# 	}
# 	$('#myModal').modal('hide');
# }
#
# function save_comment(itemid, context, issue, sgid, callback) {
# 	$.ajax({
# 		url: "/ajax.php",
# 		data: {
# 			"op": "comment_add",
# 			"sgid": sgid,
# 			"itemid": itemid,
# 			"comment": context,
# 			"wrong": issue,
# 			"rand": Math.random()
# 		},
# 		type: 'POST',
# 		success: function (response) {
# 			callback(response);
# 		}
# 	});
# }
#
# function add_tosg(type,itemid) {
# 	$("#modal-body").load('studygroup_ask.php?dialog=1&type'+type+'&itemid='+itemid);
# 	$('#myModal').modal('show');
# }
# function tosgnew(obj,type,itemid){
# 	 var comment=$('#comment_form'+type+itemid).summernote('code');
# 	if(comment!=''){
# 		$("#modal-body").load('studygroup_ask.php?dialog=1&type='+type+'&itemid='+itemid);
# 		$('#myModal').modal('show');
# 	}else{
# 		alert('請先填發問的內容!');
# 	}
#
#
# }
#
# function addessaycomment_new(obj,itemid){
# 	var comment=$('#essay_form'+itemid).summernote('code');
#     var wrong=$('input[name=w'+itemid+']:checked').val();
# 	if(comment!=''){
#
# 		$.post("ajax.php", { "op": "essaycomment_add", "itemid": itemid,"comment":comment ,"wrong":wrong,'rand':Math.random()},function(data){
# 			//alert(data);
# 			//$("#comment"+id).html("<table>"+data+"</table>");
# 			$("#essaycomment"+itemid).append(data);
# 			$('#essay_form'+itemid).summernote('reset');
# 		});
#
# 	}else{
# 		alert('no comment');
# 	}
# }
# function showalert(id){
# 	$('#'+id).parents('a').css('color',"white");
# 	$('#'+id).show().animate( {},Math.ceil(Math.random()*800), 'easeOutCubic');
# }
#
# function want_ans(type,extraid) {
# 	if($('#wantansdialog').length==0){
# 		$('body').append("<div id='wantansdialog' class='wantdialog'></div>");
# 	}
#
# 	$('#wantansdialog').load("/ajax/want_ans.php?type="+type+"&extraid="+extraid+"&mt="+0);
# 	//
# 	$('#wantansdialog').dialog({closeOnEscape: false,title:"懸賞答案",minWidth:  600,minHeight:  600});
# 	$('.ui-dialog-titlebar').addClass('wanttitle');
# 	$('.ui-dialog-titlebar-close').html("<i class='glyphicon glyphicon-remove' style='color:black'></i>");
#
#
# }
# function want_teacher(type,extraid) {
# 	//$("#modal-body").html("載入懸賞單...請稍後");
# 	//.
# 	$('#myModal').find('#modal-body').html("載入懸賞單...請稍候");
# 	$('#myModal').find('#modal-body').before('<div  id="wantbg" style=\'position:absolute;top:-20px;left:-20px\'><img src=\'/images/wanted2.png\' class=\'drop-shadow\' width=\'647\' height=\'400px\'></div>');
#
# 	$('#myModal').find('#modal-body').removeClass("modal-content").addClass("wantedbg");
#
# 	$('#myModal').on('hidden.bs.modal', function () {
# 		$('#wantbg').remove();
# 		$('#myModal').find('#modal-body').removeClass("wantedbg").addClass("modal-content");
# 	})
# 	$('#myModal').find('#modal-body').load("/ajax/want_template.php?type="+type+"&extraid="+extraid);
# 	$('#myModal').modal('show');
#
# }
# function diamond_bank(money){
# 	var nowmoney=parseInt($('#mydiamond').attr('real'));
# 	$('#mydiamond').html(nowmoney+money);
# 	$('#mydiamond').attr('real',nowmoney+money);
# }
# function want_open(type,extraid) {
# 	var content=$('#want_content').val();
# 	if(content==""){
# 		mytoast('請詳細描述你的問題!','發起失敗','danger');
# 		return false;
# 	}
# 	$('#myModal').modal('hide');
# 	myloading.Show("發起懸賞中，請稍候...");
#
# 	$.ajax({
# 		cache:false,
# 		dataType:'json',
# 		url: "/ajax/want_open.php",
# 		data: {
# 			"type": type,
# 			"extraid": extraid,
# 			"content": content,
# 			"rand": Math.random()
# 		},
# 		type: 'POST'
#
# 	}).fail(function() {
# 		myloading.Hide();
# 		alert( "系統忙碌中，請稍候..." );
# 	}).success(function (response) {
# 		myloading.Hide();
# 		if(response.status==false){
# 			$.toaster({ priority : "warning", title : "失敗", message : "你的鑽石不足!" });
# 		}else{
# 			$.toaster({ priority : "success", title : "發起成功", message : "如果有勇者將會主動通知您!(-10枚鑽石)" });
# 			$("#want_"+type+"_"+extraid+"_btn").addClass("disabled").html("懸賞中");
# 			diamond_bank(-10);
# 			loaditem(type,extraid);
# 		}
#
#
#
# 	});
# }
# $(".row-stat").mouseover(function() {
#   $(this).find(".row-stat-label").css("color","white");
#   $(this).find(".row-stat-value").css("color","white");
#    $(this).css("background-color","#428BCA");
# });
# $(".row-stat").mouseout(function() {
#   $(this).find(".row-stat-label").css("color","");
#   $(this).find(".row-stat-value").css("color","");
#   $(this).css("background-color","");
# });
# function loadmore_new(targetlist,opfunc,extra){
# 			//var e=extra.encode();
# 			var loading=$("#"+targetlist).attr("loading");
# 			if(loading!="1"){
# 				$("#"+targetlist).append("<div class='loading'>載入中，請稍候....</div>");
# 				$("#"+targetlist).next('.loading').show();
# 				//alert("2");
# 				//$("#"+targetlist).addClass('loading');
# 				var offset=parseInt($("#"+targetlist).attr("offset"));
# 				var limit=parseInt($("#"+targetlist).attr("limit"));
# 				var maxid=$("#"+targetlist).attr("maxid");
# 				$("#"+targetlist).attr("offset",offset+limit);
# 				if(!extra){
# 					extra= new Object;
# 				}
# 				extra.op=opfunc;
# 				extra.offset=offset;
# 				extra.limit=limit;
# 				extra.maxid=maxid;
# 				//
# 				$("#"+targetlist).attr("loading","1");
#
# 				$.get("ajax.php", extra,
# 				function(data){
#
# 					$(".loading").remove();
# 					if(data!=''){
# 						//alert(targetlist);
# 						$("#"+targetlist).append(data);
# 						$("#"+targetlist).attr("loading","0");
# 						//$("#"+targetlist).next('.loading').hide();
# 						//$("#"+targetlist).removeClass('loading');
# 					}else{
# 						$("#"+targetlist).attr("loading","0");
# 						$("#"+targetlist).append('<div>已經沒有資料了</div>');
# 					}
# 					//dialoglink();
# 				});
# 			}
# }
# function ytoken(addtoken){
#
# 	var nowtoken=parseInt($('#ytoken').attr('real'));
# 	nowtoken=nowtoken+(addtoken);
# 	$('#ytoken').attr('real',nowtoken).html(shorttoken(nowtoken));
# }
# function shorttoken(nowtoken){
# 	var shorttokennum=nowtoken;
# 	if(nowtoken>100000){
# 		shorttokennum=Math.floor(nowtoken/10000)+"萬";
# 	}
# 	return shorttokennum;
# }
#
# function showUsertask(){
#
# 	var zoom1=(Math.floor($(window).width()*10/980)/10);
# 	var zoom2=(Math.floor($(window).height()*10/500)/10);
# 	var zoom=Math.min(zoom1,zoom2);
# 	$('.modal-dialog').before('<div id="mycontent" style="width:980px;position:relative;margin-left:auto;margin-right:auto;top:10px;z-index:9999;"></div>');
# 	/*
# 	$('#mycontent').css({
# 		"zoom":zoom,
# 	  '-moz-transform':'scale('+zoom+')',
# 	  '-webkit-transform':'scale('+zoom+')',
# 	  '-o-transform':'scale('+zoom+')',
# 	  '-ms-transform':'scale('+zoom+')',
# 	'transform': 'scale('+zoom+')'});
# 	*/
# 	$('#myModal').find('.modal-content2').hide();
# 	$('#mycontent').load("https://yamol.tw/ajax/user_tasks.php",function(){
# 		var hh=$('#mycontent').height();
# 		var h=$(window).height();
# 		//alert(hh+" "+h);
#
# 		$('#mycontent').css("top",Math.ceil((h-hh)/2));
# 	});
# 	$('#myModal').modal();
# 	$('#myModal').on('hidden.bs.modal', function () {
# 		$('#mycontent').remove();
# 		$('#myModal').find('.modal-content2').show();
# 	})
# }
# function taskshow(){
# 	$('#headertasks').addClass('flash animated').one('webkitAnimationEnd mozAnimationEnd MSAnimationEnd oanimationend animationend', function(){
# 				 $(this).removeClass('flash animated');
# 				});
# }
#
# function loaditemcomment(type,itemid,master){
# 	loaditem(type,itemid,master);
# }
#
# function want_rating(type,ansid,extraid,jsid,obj){
# 	$(obj).addClass("item_want_good_disable").removeClass("item_want_good");
# 	$.ajax({
# 	  url: "ajax/want_rating.php?type="+type+"&extraid="+extraid+"&ansid="+ansid+"&"+Math.random(),
# 	  dataType: "json"
# 	})
#   .done(function( data ) {
# 	  if(data.status==true){
# 		  $('#'+jsid).html(parseInt($('#'+jsid).html())+1);
# 	  }else{
# 		  alert('你已經投票過了!');
# 	  }
# 	//
#   });
#
# }
# function showDiamondBank(){
#
#
# 	$('#myModal').on('hidden.bs.modal', function () {
#
# 	})
# 	$('#myModal').find('#modal-body').load("/ajax/diamon_banklist.php?");
# 	$('#myModal').modal('show');
#
#
#
# }
#
# function showallcomment(type,itemid,jsid){
# 	$('#'+jsid).load("ajax/showallcomment.php?type="+type+"&itemid="+itemid);
# }
# function showitemlistmemo(type,itemid,obj){
#
#
# 	$(obj).parent().removeClass('tab_highline');
# 	$.ajax({
# 	   "url":'/ajax/showitemlistmemo.php?type='+type+'&itemid='+itemid
# 	}).done(function(data) {
# 	  $("#menu1"+type+itemid).html(data);
# 	  $('.barrating').barrating({
# 				theme: 'bootstrap-stars',
# 				showValues: false,
# 				showSelectedRating: false
# 			});
# 	});
# 	ga('send','event','私有筆記','列表','點擊','1');
# }
# function rating_memo(id,jsid,score){
# 	$('#'+jsid).load("/ajax/itemmemo_rating.php?id="+id+"&score="+score);
#
# }
#
# function show_exchange() {
# 	$('#myModal').find('#modal-body').load("/ajax/exchange.php?");
# 	$('#myModal').modal('show');
# 	$('#myModal').on('hidden.bs.modal', function () {
# 		$('#myModal').find('#modal-body').html('');
# 	});
# }
#
# function start_exchange() {
# 	$selected = $('#exchange-select').find("option:selected").attr('value');
# 	console.log($selected);
# 	$.ajax({
# 	   "url":'/ajax/diamond_exchange.php',
# 	   dataType:"json",
# 	   data: { type: $selected }
# 	}).done(function(data) {
# 		if(data.result == true){
# 			mytoast(data.msg);
# 			diamond_bank(data.amount);
# 			$('#myModal').modal('hide');
# 		}else{
# 			alert(data.msg);
# 		}
# 	});
# }
#
# function diamond_to_vip(){
# 	$.ajax({
# 	   "url":'/ajax/diamond_to_vip.php',
# 	   dataType:"json"
# 	}).done(function(data) {
# 		console.log(data);
# 		if(data.status==false){
# 			alert('你的Y幣不足喔!');
# 		}else{
# 			mytoast('兌換成功! VIP到期時間'+data.msg);
# 			diamond_bank(-1000);
# 			$('#myModal').modal('hide');
#
# 		}
# 	});
# }
# function showimg(el){
# 	var img=$(el).attr("src");
# 	var zoomimg=img;
# 	$('<div class="easyzoom easyzoom--overlay" style="border:1px solid red" ><a href="'+zoomimg+'"><img src="'+img+'" width="100%"/></a></div>').insertAfter( el );
# 	$(el).hide();
# 	$('.easyzoom').easyZoom();
# }
# function itemmemo_sell(id,obj){
# 	if($(obj).text()=='販賣中'){
# 		$(obj).text("開啟販賣");
# 		$(obj).removeClass('btn-danger').addClass('btn-default');
# 		$.ajax({
# 				  url: "/ajax/itemmemo_sell.php?id="+id+"&op=close",
# 				  context: document.body
# 		});
# 		mytoast("已經關閉販賣");
# 	}else{
# 		$(obj).text("販賣中");
# 		$(obj).removeClass('btn-default').addClass('btn-danger');
# 		$.ajax({
# 				  url: "/ajax/itemmemo_sell.php?id="+id+"&op=sell",
# 				  context: document.body
# 		});
# 		mytoast("已經開啟販賣");
#
# 	}
# }
# function buywant_show(ansid,type){
#
# 	$('#myModal').on('hidden.bs.modal', function () {
#
# 	})
# 	$('#myModal').find('#modal-body').html('');
# 	$('#myModal').find('#modal-body').load("/ajax/buywant_show.php?type="+type+"&ansid="+ansid);
# 	$('#myModal').modal('show');
# }
# function showdetailans_edit(type,ansid){
# 	$('#myModal').find('#modal-body').load("/ajax/detailans_edit.php?type="+type+"&ansid="+ansid);
# 	$('#myModal').modal({keyboard: false,backdrop:"static"}).modal('show');
# }
# function remove_wronglist(itemid){
# 	if(confirm('是否確定移除?將不能恢復喔!')){
# 		$('#wrong'+itemid).fadeOut();
# 		newApi.delete('v3/often_errors/questions/'+itemid);
# 	}
# }
# function remove_todayerror(itemid){
# 	if(confirm('是否確定移除?將不能恢復喔!')){
# 		$('#i_'+itemid).fadeOut();
# 		$.ajax({
# 				  url: "/ajax/todayerror_remove.php?itemid="+itemid,
# 				  context: document.body
# 		});
# 	}
# }
# function refresh_content(id){
# 	$('#i_c_'+id).html('載入中...請稍候...');
# 	$('#i_c_'+id).load('/ajax/refresh_content.php?type=item&id='+id);
# }
# function show_detailans_all(id){
# 	$('#detailans_summary_'+id).hide();
# 	$('#detailans_all_'+id).show();
# }
# function startSellDetailans(button, itemid, ansid) {
# 	if (confirm('確定開始販售嗎?')) {
#
# 		$.ajax({
# 		  type: "POST",
# 		  url: "/ajax.php",
# 		  data: {
# 			"op": "add_detailans_as_want",
# 			"itemid": itemid,
# 			"ansid": ansid
# 			},
# 		  dataType: 'json'
# 		}).done(function(data){
# 			if(data.status==='ok'){
# 				mytoast("開啟販賣，開始累積鑽石");
# 				$(button).replaceWith("<button class='btn btn-default' onclick='stopSellDetailans(this" + "," + itemid + "," + ansid + ")'>停止販售</button>");
# 			}else{
# 				mytoast("字數太短，無法開啟販賣！");
# 			}
#
# 		});
#
# 	} else {
#
# 	}
# }
#
# // 仍然是 want_item, soft-delete via detailans_delete
# function stopSellDetailans(button, itemid, ansid) {
# 	if (confirm('確定停止販售嗎?')) {
# 		$.post("/ajax.php", {
# 			"op": "soft_delete_detailans_as_want",
# 			"itemid": itemid,
# 			"ansid": ansid
# 		}, function(data){
# 			$(button).replaceWith("<button class='btn btn-primary' onclick='startSellDetailans(this" + "," + itemid + "," + ansid + ")'>開啟販售</button>");
# 		});
#
# 	} else {
#
# 	}
# }
#
# $(function() {
# 	const pageName = '';
# 	const isAdmin = parseInt('') === 1;
# 	const targetPageName = ['循序漸進模式', '試卷模式', '自由測驗']
# 	const isTarget = targetPageName.findIndex(el => el === pageName) > -1;
# 	if (isTarget) {
# 		if (localStorage.getItem('examoptionEssayAlert') === null) {
# 			$('#myModal').find('#modal-body').html('<div>本模式測驗中不會出現非選題，欲測驗非選題請到非選模式測驗。</div>');
# 			$('#myModal').modal('show');
# 			localStorage.setItem('examoptionEssayAlert', true);
# 		}
# 	}
# });
# </script>
# <div class="alert alert-danger" id="toslow" style="display:none"></div>
# <div class="navbar" id="headernavbar">
# <div class="container">
# <div class="navbar-header">
# <table>
# <tr>
# <td>
# <div class="navbar-brand navbar-brand-image" style="padding:0px !important;">
# <ul class="nav navbar-nav noticebar navbar-left">
# <li class="pointer">
# <a class="mytooltip" data-placement="bottom" href="#" id="sitemenubtn" style="color:white;margin:10px;padding:0px;" title="功能列表"><span class="glyphicon glyphicon-menu-hamburger" style="font-size:35px;"></span></a>
# </li></ul>
# <script>
# 		var href = document.location.href;
# 		var globalherf = "";
# 		if (href.indexOf('test0.yamol.tw') >= 0) {
# 			globalherf = 'http://test0.yamol.tw/';
# 		} else if (href.indexOf('yamol.tw') >= 0) {
# 			globalherf = 'https://yamol.tw/';
# 		} else {
# 			globalherf = 'http://localhost/';
# 		}
#
# 		function showslider(json) {
# 			$('#slider').html(json.html);
# 		}
# 		$(function() {
# 			$("body").after('<div id="slider" class="slider" style="background-color:black"></div>');
#
# 			slider = $("#slider").slideReveal({
# 				width: "200px",
# 				// push: false,
# 				position: "left",
# 				speed: 600,
# 				trigger: $("#sitemenubtn"),
# 				// autoEscape: false,
# 				show: function(obj) {
#
# 					$.ajax({
# 						url: globalherf + "global/ajax/sitepanel.php?on_site=",
# 						dataType: "jsonp",
# 						jsonpCallback: "showslider"
# 					});
#
# 				},
# 				shown: function(obj) {
# 					console.log(obj);
# 				},
# 				hide: function(obj) {
# 					console.log(obj);
# 				},
# 				hidden: function(obj) {
# 					console.log(obj);
# 				},
# 				overlay: true,
# 				overlayColor: 'rgba(255,255,255,0.5)'
# 			});
#
#
# 		});
# 	</script>
# </div>
# <td>
# <a href="main.php"><img src="https://cdn.yamol.net/images/linepic.png?2021070801" style="line-height:50px;height:50px;margin:5px;" title=""/></a>
# <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
# <i class="fa fa-cogs"></i>
# </button>
# </td></td></tr></table>
# </div>
# <div class="navbar-collapse collapse">
# <ul class="nav navbar-nav noticebar navbar-left">
# </ul>
# <ul class="nav navbar-nav noticebar navbar-right">
# <li>
# <a href="forum.php?id=10&amp;offset=0&amp;clearup=1" style="color:white">
# <span class="notif-dot hidden" id="announcement_alert">●</span>
# <i class="fa fa-bullhorn"></i> 公告
# </a>
# </li>
# <li>
# <a href="search.php" style="color:white">
# <i class="fa fa-search"></i> 搜尋
# </a>
# </li>
# <li>
# <a href="support.php?from_url=%2Fitem-783394.htm" style="color:white">
# <i class="fa fa-question-circle"></i> 回報 </a>
# </li>
# <script type="text/javascript">
# 					$('#support-open-anchor').on('click', function(e) {
# 						e.preventDefault();
# 													mytoast("請先登入才可以使用問題回報!"); 					});
# 				</script>
# <li>
# <a href="register.php" style="color:white" target="_parent">註冊</a>
# </li>
# <li>
# <a href="mylogin.php" style="color:white" target="_parent">登入</a>
# </li>
# <li>
# <a onclick="goQRCode()" style="cursor:pointer;color:black;margin-left:5px;font-size:40px;padding:12px 0px 12px 0px;">
# <i class="fa fa-qrcode" style="color:white;font-size:22px"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="channel_header">
# <div class="container">
# <div class="col-sm-6 col-md-6 col-lg-6" style="padding:0px;">
# <div class="channel">
# <table width="100%"><tr><td valign="top">
# <i class="glyphicon glyphicon-link"> <i>
# <td>
# <div id="noticelist">
# <ul><li class="headerchannel"><a href="forum_topic.php?id=22712">疫情嚴峻，請大家一起為防疫努力</a></li><li class="headerchannel"><a href="forum_topic.php?id=22704">精神分析學派(考前快速複習)</a></li><li class="headerchannel"><a href="forum_topic.php?id=22713">考選部因應疫情發展，近期2項國家考試延後舉行</a></li><li class="headerchannel"><a href="forum_topic.php?id=431">諮商與輔導理論派別整理</a></li><li class="headerchannel"><a href="forum_topic.php?id=22714">高普考重大變革！停考公文、英文比重增112年起實施</a></li><li class="headerchannel"><a href="forum_topic.php?id=541">各種效應整理</a></li><li class="headerchannel"><a href="forum_topic.php?id=22692">企業管理筆記</a></li><li class="headerchannel"><a href="forum_topic.php?id=22701">避免考試群聚 外語導遊、地政士等國考延期</a></li><li class="headerchannel"><a href="forum_topic.php?id=525">國語文 + 專業國文（修辭法整理）</a></li></ul></div>
#
# </td></i></i></td></tr></table>
# </div>
# <script>
#
#
# $(function() {
#    $("#noticelist").Scroll({ line: 1, speed: 500, timer: 10000, up: "but_up", down: "but_down" });
#
# });
# </script>
# </div>
# <div class="col-sm-6 col-md-6 col-lg-6" style="padding:0px;">
# <div class="channel">
# <table width="100%"><tr><td valign="top" width="10px">
# <i class="fa fa-bullhorn"> <i>
# <td>
# <div id="channellist"></div>
# <td align="right" valign="top" width="70px">
# <button class="btn btn-info btn-mini" onclick="showchannelinsert()" style="padding:2px;font-size:11px">喊話</button>
# </td></td></i></i></td></tr></table>
# </div>
# <script>
# var time1;
# var time2;
# function channel_load(){
# 	$('#channellist').load("ajax/channel_list.php");
# }
# function showchannelinsert(){
#
# 	var zoom=(Math.ceil($(window).width()*10/1200)/10);
#
# 	$('.modal-dialog').before('<div id="mycontent" style="position:absolute;top:0;left:0px;z-index:9999;"></div>');
# 	$('#mycontent').css("zoom",zoom);
# 	$('#myModal').find('.modal-content2').hide();
# 	$('#mycontent').load("https://yamol.tw/ajax/channel_insert_ajax.php");
# 	$('#myModal').modal();
# 	$('#myModal').on('hidden.bs.modal', function () {
# 		$('#mycontent').remove();
# 		$('#myModal').find('.modal-content2').show();
# 	})
# }
# $(function() {
#     channel_load();
# });
# </script>
# </div>
# </div>
# </div>
# <style>
# 	.minifix {
# 		border-bottom: 1px solid white;
# 		z-index: 502;
# 		background-color: #7ECDF4;
# 		position: fixed;
# 		height: 60px;
# 		background-position: 0px 70px;
# 	}
#
# 	.minifix .mainbar-nav>li>a {}
#
# 	.minifix .mainbar-nav>li>a {
# 		padding: 12px;
# 	}
#
# 	.minifix .mainbar-nav>li>a>i {
# 		display: none;
# 	}
#
# 	.upheader {
# 		display: none
# 	}
#
# 	.minifix .upheader {
# 		display: block;
# 		margin-top: -5px !important;
# 	}
#
# 	.minifix .upheader>li>a>i {
# 		display: block !important;
# 		font-size: 20px;
# 	}
#
# 	.minifix .mainbar-collapse.collapse {
# 		padding-top: 0px;
# 		margin-top: -10px;
# 	}
#
# 	.submenu>li>a {
# 		font-size: 18px !important;
# 	}
#
# 	.headerBarflexWrap {
# 		flex-wrap: nowrap;
# 		display: flex;
# 		justify-content: center;
# 	}
# </style>
# <div id="headerfixedspace" style="height:190px;display:none"></div>
# <div class="mainbar" id="mainbar">
# <div class="container">
# <button class="btn mainbar-toggle" data-target=".mainbar-collapse" data-toggle="collapse" type="button">
# <i class="fa fa-bars"></i>功能列表
# </button>
# <div class="mainbar-collapse collapse">
# <ul class="nav navbar-nav pull-right mainbar-nav upheader">
# <li>
# <a class="mytooltip" data-placement="bottom" onclick="$(window).scrollTop(0)" title="置頂"><i class="fa fa-chevron-up"></i></a>
# </li>
# </ul>
# <ul class="nav navbar-nav mainbar-nav headerBarflexWrap" id="quick_btn">
# <li class="dropdown" id="circlebtn">
# <a href="examoption_circlenew.php"><i class="fa fa-sort-amount-asc nav-icon"></i><b>循序</b> </a>
# </li>
# <li class="dropdown" id="exambtn">
# <a href="examoption_exam.php"><i class="fa fa-bars nav-icon"></i> <b>試卷</b></a>
# </li>
# <li class="dropdown" id="essaybtn">
# <a href="https://app.yamol.tw/examoption_essay">
# <i class="fa nav-icon">
# <img src="images/icons/pen-alt.svg" style="filter: drop-shadow(1px 1px 2px #3E8851);">
# </img></i>
# <b>非選</b>
# </a>
# </li>
# <li class="dropdown" id="errorbtn">
# <a href="examoption_error.php"><i class="fa fa-times nav-icon"></i> <b>錯題</b> </a>
# </li>
# <li class="dropdown" id="freebtn">
# <a href="https://app.yamol.tw/examoption_free"><i class="fa fa-random nav-icon"></i> <b>自由</b></a>
# </li>
# <li class="dropdown" id="champbtn">
# <a href="examoption_champ.php"><i class="fa fa-trophy nav-icon"></i> <b>冠軍</b></a>
# </li>
# <li class="dropdown" id="examoption">
# <a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="javascript:;">
# <i class="fa fa-dashboard"></i>
# <b>練功房</b>
# <span class="caret"></span>
# </a>
# <ul class="dropdown-menu" style="width:500px">
# <li class="col-sm-12">
# <ul class="submenu col-sm-6 list-group">
# <li class="list-group-item" id="examinfobtn"><a href="examinfo.php"><i class="fa fa-tasks nav-icon"></i> 考試一覽表 </a></li>
# <li class="list-group-item"><a href="examoption_imp.php"><i class="fa fa-exclamation nav-icon"></i> 近期刊誤</a></li>
# <li class="list-group-item" id="exambtn"><a onclick='moveinfo("exambtn","試卷測驗已經搬家，未來請從這邊進入")'><i class="fa fa-bars nav-icon"></i> 試卷模式</a></li>
# <li class="list-group-item"><a onclick='moveinfo("circlebtn","循序漸進已經搬家，未來請從這邊進入")'><i class="fa fa-sort-amount-asc nav-icon"></i> 循序漸進模式 </a></li>
# <li class="list-group-item"><a onclick='moveinfo("champbtn","冠軍賽已經搬家，未來請從這邊進入")'><i class="fa fa-trophy nav-icon"></i> 冠軍賽</a></li>
# <li class="list-group-item"><a onclick='moveinfo("errorbtn","今錯已經搬家，未來請從這邊進入")'><i class="fa fa-times nav-icon"></i> 今日錯題測驗 </a></li>
# <li class="list-group-item"><a onclick='moveinfo("errorbtn","近錯已經搬家，未來請從這邊進入")'><i class="fa fa-times-circle nav-icon"></i> 近期錯題測驗 </a></li>
# <li class="list-group-item"><a href="examoption_latesttest.php"><i class="fa fa-upload nav-icon"></i> 最近測驗</a></li>
# <li class="list-group-item"><a href="examoption_nofinal.php"><i class="fa fa-file-o nav-icon"></i> 未完成試卷</a></li>
# </ul>
# <ul class="submenu col-sm-6 list-group">
# <li class="list-group-item"><a href="examoption_wronglist.php"><i class="fa fa-question-circle nav-icon"></i> 常錯題目</a></li>
# <li class="list-group-item"><a onclick='moveinfo("circlebtn","個人題庫已經合併到循序漸進，請到循序漸進去測驗喔!")'><i class="fa fa-star nav-icon"></i> 個人題庫總複習</a></li>
# <li class="list-group-item"><a onclick='moveinfo("freebtn","自由測驗已經搬家囉，未來請從這邊進入")'><i class="fa fa-random nav-icon"></i> 自由測驗</a></li>
# <li class="list-group-item"><a onclick='moveinfo("circlebtn","關鍵字測驗已經合併到循序漸進，請到循序漸進去測驗喔!")'><i class="fa fa-terminal nav-icon"></i> 關鍵字測驗</a></li>
# <li class="list-group-item"><a href="examoption_userp.php"><i class="fa fa-bullseye nav-icon"></i> 精熟測驗</a></li>
# <li class="list-group-item"><a href="examoption_sg.php"><i class="fa fa-users nav-icon"></i> 讀書會測驗</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="dropdown" id="secretary">
# <a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="javascript:;">
# <i class="fa fa-medkit"></i>
# 考試秘書 <span class="caret"></span>
# </a>
# <ul class="dropdown-menu" style="width:500px">
# <li class="col-sm-12">
# <ul class="submenu col-sm-6 list-group">
# <li class="list-group-item"><a href="examoption.php"><i class="fa fa-bar-chart-o nav-icon"></i> 各科能力分析</a></li>
# <li class="list-group-item" id="gastools"><a href="gas_tools.php"><i class="glyphicon glyphicon-plus-sign nav-icon"></i>打氣工具</a></li>
# <li class="list-group-item"><a href="user_itemmemo.php"><i class="fa fa-book nav-icon"></i> 私人筆記</a></li>
# <li class="list-group-item"><a href="timeclock_list.php" onclick="ga('send','event','考試秘書','打卡','點擊','1');"><i class="fa fa-clock-o nav-icon"></i> 打卡</a></li>
# <li class="list-group-item"><a href="support.php?op=select"><i class="fa fa-comment-o nav-icon"></i> 發問問題</a></li>
# <li class="list-group-item"><a href="note.php"><i class="fa fa-book nav-icon"></i> 線上筆記</a></li>
# <li class="list-group-item"><a href="calendar.php"><i class="fa fa-calendar nav-icon"></i> 考用行事曆</a></li>
# <li class="list-group-item"><a href="examoption_myupload.php"><i class="fa fa-upload nav-icon"></i> 我上傳的試卷</a></li>
# </ul>
# <ul class="submenu col-sm-6 list-group">
# ...
# 							var str2 = '([^a-z^A-Z])(' + thisw + ')([^a-z^A-Z])';
# 							var temp_reg = new RegExp(str2, "i");
# 							res = res.replace(temp_reg, "$1<t class='dict'>$2</t>$3");
# 						}
# 					});
# 					res = res.replace("重新載圖", "");
# 					res = res.replace(/\(([A-E])\)/g, "<br/>($1)");
# 					$(this).after("<Div class='itemcontent_dict'><mydiv>" + res + "</mydiv></div>");
# 				}
# 			});
# 			$('.dict').click(function() {
# 					var res = encodeURIComponent($(this).html());
# 					//$('#translation_form').submit();
#
# 					$.ajax({
# 						method: "POST",
# 						url: "/ajax.php?op=dictionary_search_task_check"
# 					}).done(function(response) {});
#
# 					window.open('dictionary_search.php?p=' + res, 'dict', config = 'height=500,width=900');
#
# 				})
# 				.hover(function() {
# 					$(this).addClass("sogreen").addClass("tran");
# 				}, function() {
# 					$(this).removeClass("sogreen").removeClass("tran");
# 				});
#
# 			dict_open = true;
# 			mytoast("查單字功能打開，直接點選英文單字就可以查詢!");
# 			$(".dictionary_tools").removeClass('dictionary_off');
# 			$(".dictionary_tools").find('i').html("開");
# 		} else {
# 			dict_open = false;
# 			$(".itemcontent").show();
# 			$(".itemcontent_dict").remove();
# 			$(".dictionary_tools").addClass('dictionary_off');
# 			$(".dictionary_tools").find('i').html("關");
#
# 		}
#
#
#
#
# 	}
#
# 	function dictionary(type, itemid, obj) {
#
# 		if ($('#content_d_' + type + itemid).length > 0) { //已經載入
# 			if ($('#content_' + type + itemid).hasClass('hide')) {
# 				$(obj).addClass('dictionary_off');
# 				$(obj).find('i').html("關");
# 				$('#content_' + type + itemid).removeClass('hide');
# 				$('#content_d_' + type + itemid).addClass('hide');
# 			} else {
# 				$(obj).removeClass('dictionary_off');
# 				$(obj).find('i').html("on");
# 				$('#content_' + type + itemid).addClass('hide');
# 				$('#content_d_' + type + itemid).removeClass('hide');
# 			}
# 		} else {
# 			$('#content_' + type + itemid).after("<span class='itemcontent' id='content_d_" + type + itemid + "'></span>");
# 			$.ajax({
# 				url: "ajax/showitem.php?op=dictionary&type=" + type + "&itemid=" + itemid,
# 				context: document.body
# 			}).done(function(data) {
# 				mytoast("查單字功能打開，直接點選英文單字就可以查詢!");
# 				$(obj).removeClass('dictionary_off');
# 				$(obj).find('i').html("開");
# 				$('#content_' + type + itemid).addClass('hide');
# 				$('#content_d_' + type + itemid).html(data);
# 				$('.dict').click(function() {
# 						var res = encodeURIComponent($(this).html());
# 						//$('#translation_form').submit();
# 						window.open('dictionary_search.php?p=' + res, 'dict', config = 'height=500,width=900');
#
# 					})
# 					.hover(function() {
# 						$(this).addClass("sogreen").addClass("tran");
# 					}, function() {
# 						$(this).removeClass("sogreen").removeClass("tran");
# 					});
# 			});
# 		}
# 	}
#
#
#
# 	function api_recommand(authoruserid) {
# 		$.ajax({
# 			url: "https://api.yamol.tw/api/web/recommend?accessToken=",
# 			method: "POST",
# 			crossDomain: true,
# 			data: {
# 				authoruserid: authoruserid,
# 				type: 'usermenu'
# 			}
# 		}).done(function(data) {
# 			$('.friendbtn' + authoruserid).each(function() {
# 				$(this).html(data);
# 			});
# 		});
# 	}
#
# 	function api_removeFriend(authoruserid) {
# 		$.ajax({
# 			url: "https://api.yamol.tw/api/web/removeFriend?accessToken=",
# 			method: "POST",
# 			crossDomain: true,
# 			data: {
# 				authoruserid: authoruserid,
# 				type: 'usermenu'
# 			}
# 		}).done(function(data) {
# 			$('.friendbtn' + authoruserid).each(function() {
# 				$(this).html(data);
# 			});
# 		});
# 	}
#
# 	function api_showTodayItemRank() {
# 		$('#modal-body').html('載入中...');
# 		$.ajax({
# 			url: "https://api.yamol.tw/api/web/block/todayexamrank?accessToken=",
# 			method: "GET",
# 			crossDomain: true
# 		}).done(function(data) {
# 			$('#modal-body').html(data);
# 		});
# 		$('#myModal').modal('show');
# 	}
#
# 	function api_showReponseRank() {
# 		$('#modal-body').html('載入中...');
# 		$.ajax({
# 			url: "https://api.yamol.tw/api/web/block/reponserank?accessToken=",
# 			method: "GET",
# 			crossDomain: true
# 		}).done(function(data) {
# 			$('#modal-body').html(data);
# 		});
# 		$('#myModal').modal('show');
# 	}
#
# 	function api_showtestrank(testid, score) {
# 		$('#modal-body').html('載入中...');
# 		$.ajax({
# 			url: "https://api.yamol.tw/api/web/block/testrank/" + testid + "/" + score + "?accessToken=",
# 			method: "GET",
# 			crossDomain: true
# 		}).done(function(data) {
# 			$('#modal-body').html(data);
# 		});
# 		$('#myModal').modal('show');
# 	}
#
# 	function api_save_itemmemo(type, itemid) {
# 		var memoid = 'memo' + type + itemid;
# 		var isEmpty = false;
# 		if ($('#itemmemo_sell' + type + itemid).prop("checked")) {
# 			var sell = 1;
# 		} else {
# 			var sell = 0;
# 		}
#
# 		var content = $('#memotext' + type + itemid).summernote('code');
# 		if ($('#memotext' + type + itemid).summernote('isEmpty')) {
# 			isEmpty = true;
# 		}
# 		var hasImg = content.split('<img ').length > 1;
#
# 		var contentLength = $('<div>').html(content).text().length;
# 		var tags = $("#tags" + type + itemid).val();
#
# 		// 1. 沒有文字, 2. 沒有圖片, 3. 沒有標籤, 三個都沒有的話不能新增
# 		if (contentLength < 1 && !hasImg && tags.length < 1) {
# 			$("#memo" + type + itemid).show();
# 			$('#pen' + memoid).show();
# 			$('#ajax_' + memoid).remove();
# 			$("#itemtags" + type + itemid).show();
# 			var p = $("#memo" + type + itemid).offset();
# 			$("html, body").animate({
# 				scrollTop: p.top - 30
# 			}, 600);
# 			return mytoast("內容空白，無法儲存");
# 		}
#
# 		// 1. 文字不滿5個字 2. 沒有圖片, 兩個都沒有的話不能販賣
# 		if (sell === 1 && contentLength < 5 && !hasImg) {
# 			return mytoast("未滿5字，無法販售");
# 		}
#
# 		var NewArray = tags.replace(/,/gi, '</span> <span class="label label-danger">');
# 		$("#itemtags" + type + itemid).html('<span class="label label-warning">' + NewArray + '</span>');
# 		var lowcontent = content.toLowerCase();
# 		//alert(lowcontent.indexOf("img"));
# 		$("#memo" + type + itemid).html("<i>存檔中..請稍候...</i>").show();
# 		$.post("https://api.yamol.tw/api/web/memo?accessToken=", {
# 			type: type,
# 			itemId: itemid,
# 			sell: sell,
# 			memoContent: isEmpty ? '' : content,
# 			tags: tags
# 		}).done(function() {
# 			mytoast("成功", "存檔成功");
# 			if (sell) {
# 				content = "<div class='label label-danger' style='line-height:300%;'>販賣中</div>" + content;
# 			}
# 			$("#memo" + type + itemid).html(content).show();
# 			$('#pen' + memoid).show();
# 			$('#ajax_' + memoid).remove();
# 			$("#itemtags" + type + itemid).show();
# 			var p = $("#memo" + type + itemid).offset();
#
# 			$("html, body").animate({
# 				scrollTop: p.top - 30
# 			}, 600);
# 		});
#
#
# 	}
#
# 	function api_showitemlistmemo(type, itemid, obj) {
#
#
# 		$(obj).parent().removeClass('tab_highline');
# 		$.ajax({
# 			"url": 'https://api.yamol.tw/api/web/memo/' + type + '/' + itemid + '?accessToken='
# 		}).done(function(data) {
# 			$("#memolist" + type + itemid).html(data);
# 		});
# 		ga('send', 'event', '私有筆記', '列表', '點擊', '1');
# 	}
#
#
# 	function api_memorate(memoid, score) {
# 		$.ajax({
# 				method: "POST",
# 				url: "https://api.yamol.tw/api/web/memo/rating?accessToken=",
# 				data: {
# 					memoid: memoid,
# 					score: score
# 				},
# 				dataType: "json"
# 			})
# 			.done(function(msg) {
# 				if (msg) {
# 					$('#memorating' + memoid).html(msg.newscore);
# 				}
# 			});
# 	}
#
# 	function api_report(extra_type, extra_key) {
# 		$.ajax({
# 				method: "GET",
# 				url: "https://api.yamol.tw/api/ajax/m2/report/" + extra_type + "/" + extra_key + "?accessToken="
# 			})
# 			.done(function(reponse) {
# 				$('#modal-body').html(reponse);
# 				$('#myModal').modal("show");
#
# 				setTimeout(function() {
# 					$('#modal-body').find('textarea').focus();
# 				}, 500);
#
# 			});
# 	}
#
# 	function api_report_send(btn) {
# 		reportform = $(btn).parents().find("#reportform");
# 		var title = reportform.find('input[name="title"]').eq(0).val();
# 		var key = reportform.find('input[name="key"]').eq(0).val();
# 		var type = reportform.find('input[name="type"]').eq(0).val();
# 		var content = reportform.find('textarea[name="content"]').eq(0).val();
# 		var from_url = window.location.href;
# 		if (content == '') {
# 			alert('請填原因！');
# 			return false;
# 		}
# 		$.ajax({
# 				method: "POST",
# 				url: "https://api.yamol.tw/api/ajax/m2/report/?accessToken=",
# 				data: {
# 					key: key,
# 					type: type,
# 					content: content,
# 					title: title,
# 					from_url: from_url
# 				}
# 			})
# 			.done(function(reponse) {
# 				//$('#modal-body').html(reponse);
# 				$('#myModal').modal("hide");
# 				toast("感謝回報，我們會盡快處理");
# 			});
# 	}
#
# 	function api_buymemo(btn, ansid) {
# 		$(btn).hide();
# 		$(btn).after("<div class='loading'>載入中...</div>");
# 		toast('請先登入');return false;
# 		$.ajax({
# 			url: "https://api.yamol.tw/api/ajax/web/memo/buy?accessToken=",
# 			method: "POST",
# 			crossDomain: true,
# 			data: {
# 				ansid: ansid
# 			},
# 			timeout: 10000
# 		}).done(function(data) {
# 			if (data.data.msg) {
# 				toast(data.data.msg);
# 				$(btn).next().remove();
# 				$(btn).show();
# 				return true;
# 			}
# 			if (data.data.buytype == 'diamond') {
# 				toast('-' + data.data.buymoney + '鑽');
# 				diamond_bank(-data.data.buymoney);
# 			}
# 			$(btn).next().remove();
# 			$('#memo' + ansid).after(data.data.view);
# 			$('#memo' + ansid).remove();
# 		}).fail(function(jqXHR, textStatus) {
# 			toast('發生錯誤'+textStatus+',如果有安裝卡巴斯基，請先停止卡巴斯基（不是暫停防護）後試試看');
# 			$(btn).next().remove();
# 			$(btn).show();
# 		});
# 	}
#
# 	function api_buyans(btn, ansid) {
#
# 		toast('請先登入');return false;		$(btn).hide();
# 		$(btn).after("<div class='loading'>載入中...</div>");
#
# 		$.ajax({
# 			url: "https://api.yamol.tw/api/ajax/web/detailans/buy?accessToken=",
# 			method: "POST",
# 			crossDomain: true,
# 			data: {
# 				ansid: ansid
# 			},
# 			timeout: 10000
# 		}).done(function(data) {
# 			if (data.data.msg) {
# 				toast(data.data.msg);
# 				$(btn).next().remove();
# 				$(btn).show();
# 				return true;
# 			}
# 			if (data.data.buytype == 'diamond') {
# 				toast('-' + data.data.buymoney + '鑽');
# 				diamond_bank(-data.data.buymoney);
# 			}
# 			$(btn).next().remove();
# 			$('#da_' + ansid).after(data.data.view);
# 			$('#da_' + ansid).remove();
# 		}).fail(function(jqXHR, textStatus) {
# 			toast('發生錯誤'+textStatus+',如果有安裝卡巴斯基，請先停止卡巴斯基（不是暫停防護）後試試看');
# 			$(btn).next().remove();
# 			$(btn).show();
# 		});
#
# 	}
#
# 	function api_showfriendrank(testid) {
#
# 		$('#modal-body').html('載入中...');
# 		$.ajax({
# 			url: "https://api.yamol.tw/api/ajax/web/friendrank/" + testid + "?accessToken=",
# 			method: "GET",
# 			crossDomain: true
# 		}).done(function(data) {
# 			$('#modal-body').html(data);
# 		});
# 		$('#myModal').modal('show');
# 	}
#
# 	function goExamOptionEssayClick(mt) {
# 		newApi.post('/v2/tracking_dailys', {
# 			mt,
# 			click: 1
# 		});
# 	}
#
#
#
# 	if (navigator.userAgent.indexOf('MSIE') !== -1 || navigator.appVersion.indexOf('Trident/') > 0) {
# 		alert("很抱歉，我們不再支援ie系列的瀏覽器，請換chrome瀏覽器或者下載阿摩ＡＰＰ來做測驗");
# 	}
#
#
#
#
# 	</script>
# <form action="https://yamol.tw/dictionary_search.php" id="translation_form" method="get" target="_blank">
# <input id="translation_p" name="p" type="hidden"/>
# <input name="rid" type="hidden"/>
# </form>
# <script>
#
# function shownotify(message){
#
# 	 var $toast = $('<div class="ui-loader ui-overlay-shadow ui-body-e ui-corner-all" style="width:300px"><h3>' + message + '</h3></div>');
#
#     $toast.css({
# 		 display: 'block',
#         background: '#fff',
#         opacity: 0.90,
#         position: 'fixed',
#         padding: '7px',
#         'text-align': 'center',
#         width: '290px',
#         left: ($(window).width() - 300) / 2,
#         top: 1
#     });
# 	//top: $(window).height() / 2 - 20
#     var removeToast = function(){
#         $(this).remove();
#     };
#     $toast.appendTo($.mobile.pageContainer);
#
# }
# function headtasktooltip(){
# 	$('#headertasks').css('color','black').animate({color:"white"});
# }
# $(function() {
#    // setInterval("headtasktooltip()",'30000');
# });
# </script>
# <style>
# .highlight{border:5px solid red}
#
# </style>
# <div class="modal fade" id="taskmodal" role="dialog">
# <div class="modal-dialog modal-lg">
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button">×</button>
# <h4 class="modal-title">任務說明</h4>
# </div>
# <div class="modal-body" id="taskpopcontent">
# <p>This is a large modal.</p>
# </div>
# <div class="modal-footer" id="taskfooter">
# </div>
# </div>
# </div>
# </div>
# <script>
# 		var intro = introJs();
# 		function moveinfo(id,msg){
# 			intro.setOptions({
# 			exitOnEsc:true,
# 			nextLabel:"下一步",
# 			prevLabel:"上一步",
# 			skipLabel:"跳過",
# 			doneLabel:"完成",
# 			exitOnOverlayClick:false,
# 			showStepNumbers:false,
# 			keyboardNavigation:false,
# 			showButtons:false,
# 			showBullets:false,
# 			steps: [
#
# 					{
# 					element: document.querySelectorAll('#'+id)[0],
# 					intro: msg
# 				  }
#
# 				]
# 		  });
#
# 		  intro.start();
# 		}
#
# 		</script>
# <script>
# 		(function(w, d, s, l, i) {
# 			w[l] = w[l] || [];
# 			w[l].push({
# 				'gtm.start': new Date().getTime(),
# 				event: 'gtm.js'
# 			});
# 			var f = d.getElementsByTagName(s)[0],
# 				j = d.createElement(s),
# 				dl = l != 'dataLayer' ? '&l=' + l : '';
# 			j.async = true;
# 			j.src =
# 				'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 			f.parentNode.insertBefore(j, f);
# 		})(window, document, 'script', 'dataLayer', 'GTM-NGJZ5QH');
# 	</script>
# <script data-apiurl="https://api.yamol.tw/" data-theme="0" data-token="" data-userid="" id="Yamol-Widget-Script" src="https://cdn.yamol.net/widget/index.js?v=1625736304
# &amp;2021070801"></script>
# <script>
# 	function showVimeVideo(vimeoID) {
# 		$('#myModal').modal('show');
# 		template = `<div class='text-center vimeo-iframe'><iframe src="https://player.vimeo.com/video/${vimeoID}?autoplay=1&loop=1&autopause=0" width="100%" height="360" frameborder="0" allow="fullscreen;autoplay"  allowfullscreen></iframe></div>`;
# 		$('#myModal').find('#modal-body').html(template);
# 	}
#
# 	$(document).ready(function() {
#
# 		$('#myModal').on('hidden.bs.modal', function() {
# 			$('#myModal').find('#modal-extra').html("");
# 			$('.vimeo-iframe').html("");
# 		})
# 	})
#
#
# 	function goNextTestFree(type, id, cullingDays, catid) {
# 		$('#go-free').prop('disabled', true);
# 		newApi
# 			.post('/v2/testing_papers', {
# 				type,
# 				id,
# 				culling_days: cullingDays,
# 				noEssay: true,
# 			})
# 			.then(({
# 				data
# 			}) => {
# 				window.location.href = `testpaper.php?id=${data.reponse.testid}&culling_days=${cullingDays}`;
# 			})
# 			.catch((error) => {
# 				const alert = error.response.data.alert;
# 				if (error.response.data && error.response.data.alert) {
# 					if (window.confirm('剔除後的試題已全部作答完成，是否重新開始測驗?')) {
# 						newApi.delete(`/v2/testing_papers/free/reset/${catid}`)
# 							.then(({
# 								data
# 							}) => {
# 								window.alert('自由測驗已重置');
# 							});
# 					}
# 				}
# 			})
# 			.then(() => {
# 				$('#go-free').prop('disabled', false);
# 			});
# 	}
# </script> <script>
# 		(function(i, s, o, g, r, a, m) {
# 			i['GoogleAnalyticsObject'] = r;
# 			i[r] = i[r] || function() {
# 				(i[r].q = i[r].q || []).push(arguments)
# 			}, i[r].l = 1 * new Date();
# 			a = s.createElement(o),
# 				m = s.getElementsByTagName(o)[0];
# 			a.async = 1;
# 			a.src = g;
# 			m.parentNode.insertBefore(a, m)
# 		})(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
# 		ga('create', 'UA-2165226-5', 'auto');
# 		ga('require', 'displayfeatures');
# 		ga('require', 'linkid', 'linkid.js');
# 					ga('set', 'dimension1', 'nonLogin');
# 			ga('set', 'metric1', '0.033535003662109');
# 			//ga('send', 'timing', 'timingCategory', 'timingVariable', timingValue, 'optLabel');
# 			//ga('send', 'social', 'socialNetwork', 'socialAction', 'socialTarget', {'page': 'optPagePath'});
#
# 			ga('send', 'pageview');
# 	</script>
# <script type="text/javascript">
# 			if (document.location.protocol == 'http:') {
# 				var Tynt = Tynt || [];
# 				Tynt.push('dd4OaMWw4r4jM_adbi-bpO');
# 				(function() {
# 					var s = document.createElement('script');
# 					s.async = "async";
# 					s.type = "text/javascript";
# 					s.src = 'http://tcr.tynt.com/ti.js';
# 					var h = document.getElementsByTagName('script')[0];
# 					h.parentNode.insertBefore(s, h);
# 				})();
# 			}
# 		</script>
# <script>
# 	(function(d, a, b, l, e, _) {
# 		d[b] = d[b] || function() {
# 			(d[b].q = d[b].q || []).push(arguments)
# 		};
# 		e = a.createElement(l);
# 		e.async = 1;
# 		e.charset = 'utf-8';
# 		e.src = '//static.dable.io/dist/plugin.min.js';
# 		_ = a.getElementsByTagName(l)[0];
# 		_.parentNode.insertBefore(e, _);
# 	})(window, document, 'dable', 'script');
# 	dable('setService', 'dable.io');
# 	dable('sendLog');
# </script>

# %%
"8"+"7"
# Out:
# '87'
