# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.ptt.cc/bbs/Beauty/index3738.html"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
session = requests.Session()
session.post('https://www.ptt.cc/ask/over18', data = {'from' : '/bbs/Beauty/index.html', 'yes' : 'yes'})
response = session.get(url)
soup     = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 Beauty 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/Beauty/index.html"><span class="board-label">看板 </span>Beauty</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/Beauty/index.html">看板</a>
# <a class="btn" href="/man/Beauty/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/Beauty/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/Beauty/index3737.html">‹ 上頁</a>
# <a class="btn wide" href="/bbs/Beauty/index3739.html">下頁 ›</a>
# <a class="btn wide" href="/bbs/Beauty/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628256002.A.581.html">[正妹] 原つむぎ</a>
# </div>
# <div class="meta">
# <div class="author">ReiKuromiya</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E6%AD%A3%E5%A6%B9%5D+%E5%8E%9F%E3%81%A4%E3%82%80%E3%81%8E">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3AReiKuromiya">搜尋看板內 ReiKuromiya 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/06</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">48</span></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628256279.A.6E1.html">[正妹] ももせもも</a>
# </div>
# <div class="meta">
# <div class="author">ReiKuromiya</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E6%AD%A3%E5%A6%B9%5D+%E3%82%82%E3%82%82%E3%81%9B%E3%82%82%E3%82%82">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3AReiKuromiya">搜尋看板內 ReiKuromiya 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/06</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">59</span></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628257138.A.66B.html">[正妹] 江祖平</a>
# </div>
# <div class="meta">
# <div class="author">KillerD</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E6%AD%A3%E5%A6%B9%5D+%E6%B1%9F%E7%A5%96%E5%B9%B3">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3AKillerD">搜尋看板內 KillerD 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/06</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">3</span></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628262793.A.E84.html">[正妹] 戴資穎姐姐</a>
# </div>
# <div class="meta">
# <div class="author">cjrmt</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E6%AD%A3%E5%A6%B9%5D+%E6%88%B4%E8%B3%87%E7%A9%8E%E5%A7%90%E5%A7%90">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3Acjrmt">搜尋看板內 cjrmt 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/06</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">23</span></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628263236.A.34E.html">[正妹] 醫學系實況主</a>
# </div>
# <div class="meta">
# <div class="author">minilinwesto</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E6%AD%A3%E5%A6%B9%5D+%E9%86%AB%E5%AD%B8%E7%B3%BB%E5%AF%A6%E6%B3%81%E4%B8%BB">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3Aminilinwesto">搜尋看板內 minilinwesto 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/06</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">27</span></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628263458.A.888.html">[正妹] 對岸女子跨欄</a>
# </div>
# <div class="meta">
# <div class="author">ez910115</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E6%AD%A3%E5%A6%B9%5D+%E5%B0%8D%E5%B2%B8%E5%A5%B3%E5%AD%90%E8%B7%A8%E6%AC%84">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3Aez910115">搜尋看板內 ez910115 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/06</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628265944.A.24E.html">[神人] 求照片直播主</a>
# </div>
# <div class="meta">
# <div class="author">s394033</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E7%A5%9E%E4%BA%BA%5D+%E6%B1%82%E7%85%A7%E7%89%87%E7%9B%B4%E6%92%AD%E4%B8%BB">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3As394033">搜尋看板內 s394033 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628270608.A.BA7.html">[正妹] DIA Eunice</a>
# </div>
# <div class="meta">
# <div class="author">spermjuice</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E6%AD%A3%E5%A6%B9%5D+DIA+Eunice">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3Aspermjuice">搜尋看板內 spermjuice 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">7</span></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628276011.A.457.html">[帥哥] 横浜流星</a>
# </div>
# <div class="meta">
# <div class="author">fack3170</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E5%B8%A5%E5%93%A5%5D+%E6%A8%AA%E6%B5%9C%E6%B5%81%E6%98%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3Afack3170">搜尋看板內 fack3170 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">26</span></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628298525.A.C42.html">[正妹] 粉紅色</a>
# </div>
# <div class="meta">
# <div class="author">rasiel0919</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E6%AD%A3%E5%A6%B9%5D+%E7%B2%89%E7%B4%85%E8%89%B2">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3Arasiel0919">搜尋看板內 rasiel0919 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">3</span></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628301408.A.CB6.html">[問卦] IG更新後，追蹤不見了求助</a>
# </div>
# <div class="meta">
# <div class="author">tingyo1216</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+IG%E6%9B%B4%E6%96%B0%E5%BE%8C%EF%BC%8C%E8%BF%BD%E8%B9%A4%E4%B8%8D%E8%A6%8B%E4%BA%86%E6%B1%82%E5%8A%A9">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3Atingyo1216">搜尋看板內 tingyo1216 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f0">X1</span></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628301740.A.748.html">[正妹] 眼鏡妹</a>
# </div>
# <div class="meta">
# <div class="author">cora1114</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E6%AD%A3%E5%A6%B9%5D+%E7%9C%BC%E9%8F%A1%E5%A6%B9">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3Acora1114">搜尋看板內 cora1114 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">40</span></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628302125.A.6B7.html">[正妹] 周幼婷</a>
# </div>
# <div class="meta">
# <div class="author">YESGOTO</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E6%AD%A3%E5%A6%B9%5D+%E5%91%A8%E5%B9%BC%E5%A9%B7">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3AYESGOTO">搜尋看板內 YESGOTO 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
#
# 				(本文已被刪除) [e030149116]
#
# 			</div>
# <div class="meta">
# <div class="author">-</div>
# <div class="article-menu">
# </div>
# <div class="date"> 8/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628305488.A.779.html">[正妹] 大尺碼｜肉特(578)</a>
# </div>
# <div class="meta">
# <div class="author">ckpot</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E6%AD%A3%E5%A6%B9%5D+%E5%A4%A7%E5%B0%BA%E7%A2%BC%EF%BD%9C%E8%82%89%E7%89%B9%28578%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3Ackpot">搜尋看板內 ckpot 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">2</span></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628308959.A.082.html">[正妹]幾張國師近況</a>
# </div>
# <div class="meta">
# <div class="author">cklonger</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E6%AD%A3%E5%A6%B9%5D%E5%B9%BE%E5%BC%B5%E5%9C%8B%E5%B8%AB%E8%BF%91%E6%B3%81">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3Acklonger">搜尋看板內 cklonger 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">12</span></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628309975.A.AE5.html">[正妹] 大大大優惠 </a>
# </div>
# <div class="meta">
# <div class="author">iwjwlmsc0707</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E6%AD%A3%E5%A6%B9%5D+%E5%A4%A7%E5%A4%A7%E5%A4%A7%E5%84%AA%E6%83%A0+">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3Aiwjwlmsc0707">搜尋看板內 iwjwlmsc0707 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
#
# 				(本文已被刪除) [thuash]
#
# 			</div>
# <div class="meta">
# <div class="author">-</div>
# <div class="article-menu">
# </div>
# <div class="date"> 8/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">45</span></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628313085.A.FFD.html">[正妹] 善良的急診護理師</a>
# </div>
# <div class="meta">
# <div class="author">MarkeleFultz</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E6%AD%A3%E5%A6%B9%5D+%E5%96%84%E8%89%AF%E7%9A%84%E6%80%A5%E8%A8%BA%E8%AD%B7%E7%90%86%E5%B8%AB">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3AMarkeleFultz">搜尋看板內 MarkeleFultz 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">16</span></div>
# <div class="title">
# <a href="/bbs/Beauty/M.1628317964.A.A37.html">[正妹] 排球</a>
# </div>
# <div class="meta">
# <div class="author">ReiKuromiya</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Beauty/search?q=thread%3A%5B%E6%AD%A3%E5%A6%B9%5D+%E6%8E%92%E7%90%83">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Beauty/search?q=author%3AReiKuromiya">搜尋看板內 ReiKuromiya 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/07</div>
# <div class="mark"></div>
# </div>
# </div>
# </div>
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# </body>
# </html>

# %%
selects = soup.select("div.title a")

# %%
selects
# Out:
# [<a href="/bbs/Beauty/M.1628256002.A.581.html">[正妹] 原つむぎ</a>,
#  <a href="/bbs/Beauty/M.1628256279.A.6E1.html">[正妹] ももせもも</a>,
#  <a href="/bbs/Beauty/M.1628257138.A.66B.html">[正妹] 江祖平</a>,
#  <a href="/bbs/Beauty/M.1628262793.A.E84.html">[正妹] 戴資穎姐姐</a>,
#  <a href="/bbs/Beauty/M.1628263236.A.34E.html">[正妹] 醫學系實況主</a>,
#  <a href="/bbs/Beauty/M.1628263458.A.888.html">[正妹] 對岸女子跨欄</a>,
#  <a href="/bbs/Beauty/M.1628265944.A.24E.html">[神人] 求照片直播主</a>,
#  <a href="/bbs/Beauty/M.1628270608.A.BA7.html">[正妹] DIA Eunice</a>,
#  <a href="/bbs/Beauty/M.1628276011.A.457.html">[帥哥] 横浜流星</a>,
#  <a href="/bbs/Beauty/M.1628298525.A.C42.html">[正妹] 粉紅色</a>,
#  <a href="/bbs/Beauty/M.1628301408.A.CB6.html">[問卦] IG更新後，追蹤不見了求助</a>,
#  <a href="/bbs/Beauty/M.1628301740.A.748.html">[正妹] 眼鏡妹</a>,
#  <a href="/bbs/Beauty/M.1628302125.A.6B7.html">[正妹] 周幼婷</a>,
#  <a href="/bbs/Beauty/M.1628305488.A.779.html">[正妹] 大尺碼｜肉特(578)</a>,
#  <a href="/bbs/Beauty/M.1628308959.A.082.html">[正妹]幾張國師近況</a>,
#  <a href="/bbs/Beauty/M.1628309975.A.AE5.html">[正妹] 大大大優惠 </a>,
#  <a href="/bbs/Beauty/M.1628313085.A.FFD.html">[正妹] 善良的急診護理師</a>,
#  <a href="/bbs/Beauty/M.1628317964.A.A37.html">[正妹] 排球</a>]
